# %%
import pandas as pd 
import numpy as np

# %%
filepath='C:\\Users\\progr\\OneDrive\\Desktop\\DS\\data Sets\\Entities.csv'

df=pd.read_csv(filepath)

df.head()
# Out:
#    Unnamed: 0  property_id  location_id  \
# 0           0       237062         3325
# 1           1       346905         3236
# 2           2       386513          764
# 3           3       656161          340
# 4           4       841645         3226
#
#                                             page_url property_type     price  \
# 0  https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat  10000000
# 1  https://www.zameen.com/Property/e_11_2_service...          Flat   6900000
# 2  https://www.zameen.com/Property/islamabad_g_15...         House  16500000
# 3  https://www.zameen.com/Property/islamabad_bani...         House  43500000
# 4  https://www.zameen.com/Property/dha_valley_dha...         House   7000000
#
#       location       city      province_name   latitude  longitude  baths  \
# 0         G-10  Islamabad  Islamabad Capital  33.679890  73.012640      2
# 1         E-11  Islamabad  Islamabad Capital  33.700993  72.971492      3
# ...

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#         property_id  location_id  \
# 0            237062         3325
# 1            346905         3236
# 2            386513          764
# 3            656161          340
# 4            841645         3226
# ...             ...          ...
# 168441     17355248         6754
# 168442     17355249          680
# 168443     17355250         6757
# 168444     17355251         6752
# 168445     17355287        10045
#
#                                                  page_url property_type  \
# 0       https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat
# 1       https://www.zameen.com/Property/e_11_2_service...          Flat
# 2       https://www.zameen.com/Property/islamabad_g_15...         House
# 3       https://www.zameen.com/Property/islamabad_bani...         House
# 4       https://www.zameen.com/Property/dha_valley_dha...         House
# ...                                                   ...           ...
# ...

# %%
df.isnull().sum()
# Out:
# property_id          0
# location_id          0
# page_url             0
# property_type        0
# price                0
# location             0
# city                 0
# province_name        0
# latitude             0
# longitude            0
# baths                0
# purpose              0
# bedrooms             0
# date_added           0
# agency           44071
# agent            44072
# Total_Area           0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# property_id      0
# location_id      0
# page_url         0
# property_type    0
# price            0
# location         0
# city             0
# province_name    0
# latitude         0
# longitude        0
# baths            0
# purpose          0
# bedrooms         0
# date_added       0
# agency           0
# agent            0
# Total_Area       0
# dtype: int64

# %%
df.head()
# Out:
#     property_id  location_id  \
# 4        841645         3226
# 7       1258636         3241
# 8       1402466          376
# 9       1418706         3282
# 10      1425602          429
#
#                                              page_url property_type     price  \
# 4   https://www.zameen.com/Property/dha_valley_dha...         House   7000000
# 7   https://www.zameen.com/Property/e_11_e_11_4_ap...          Flat   7800000
# 8   https://www.zameen.com/Property/dha_defence_dh...         House  50000000
# 9   https://www.zameen.com/Property/f_11_f_11_1_f_...     Penthouse  40000000
# 10  https://www.zameen.com/Property/islamabad_dipl...          Flat  35000000
#
#               location       city      province_name   latitude  longitude  \
# 4          DHA Defence  Islamabad  Islamabad Capital  33.492591  73.301339
# 7                 E-11  Islamabad  Islamabad Capital  33.698244  72.984238
# 8          DHA Defence  Islamabad  Islamabad Capital  33.540894  73.095732
# ...

# %%
df[2:4]
# Out:
#    property_id  location_id  \
# 8      1402466          376
# 9      1418706         3282
#
#                                             page_url property_type     price  \
# 8  https://www.zameen.com/Property/dha_defence_dh...         House  50000000
# 9  https://www.zameen.com/Property/f_11_f_11_1_f_...     Penthouse  40000000
#
#       location       city      province_name   latitude  longitude  baths  \
# 8  DHA Defence  Islamabad  Islamabad Capital  33.540894  73.095732      7
# 9         F-11  Islamabad  Islamabad Capital  33.679211  72.988787      5
#
#     purpose  bedrooms  date_added           agency  \
# 8  For Sale         7  10/19/2018    Easy Property
# 9  For Sale         5   6/27/2019  Crown Associate
#
#                                           agent  Total_Area
# 8  Muhammad Junaid Ceo Muhammad Shahid Director      5445.0
# 9                                   Abrar Ahmed      5445.0

# %%
df_karachi=df[df['city'] == 'Karachi']
df_karachi
# Out:
#         property_id  location_id  \
# 156           86575         6649
# 161         1010365         1674
# 163         1260475         6861
# 164         1631292         1483
# 165         1902788         6853
# ...             ...          ...
# 168441     17355248         6754
# 168442     17355249          680
# 168443     17355250         6757
# 168444     17355251         6752
# 168445     17355287        10045
#
#                                                  page_url property_type  \
# 156     https://www.zameen.com/Property/faisal_cantonm...         House
# 161     https://www.zameen.com/Property/dha_defence_dh...         House
# 163     https://www.zameen.com/Property/gulshan_e_iqba...          Flat
# 164     https://www.zameen.com/Property/d_h_a_dha_phas...         House
# 165     https://www.zameen.com/Property/scheme_33_saad...         House
# ...                                                   ...           ...
# ...

# %%
df_islamabad=df.loc[df['city']=='Islamabad']
df_islamabad
# Out:
#         property_id  location_id  \
# 4            841645         3226
# 7           1258636         3241
# 8           1402466          376
# 9           1418706         3282
# 10          1425602          429
# ...             ...          ...
# 168343     17356065          330
# 168345     17356192          174
# 168346     17356220          424
# 168348     17356247          330
# 168349     17356303         3241
#
#                                                  page_url  property_type  \
# 4       https://www.zameen.com/Property/dha_valley_dha...          House
# 7       https://www.zameen.com/Property/e_11_e_11_4_ap...           Flat
# 8       https://www.zameen.com/Property/dha_defence_dh...          House
# 9       https://www.zameen.com/Property/f_11_f_11_1_f_...      Penthouse
# 10      https://www.zameen.com/Property/islamabad_dipl...           Flat
# ...                                                   ...            ...
# ...

# %%
df['city'].unique()
# Out:
# array(['Islamabad', 'Lahore', 'Faisalabad', 'Rawalpindi', 'Karachi'],
#       dtype=object)

# %%
df['purpose'].unique()
# Out:
# array(['For Sale', 'For Rent'], dtype=object)

# %%
df_karachi['purpose']=df_karachi['purpose'].replace('For Sale','fr')
df_karachi['purpose']=df_karachi['purpose'].replace('For Sale','fs')

df_karachi
# Out:
# C:\Users\progr\AppData\Local\Temp\ipykernel_7036\3392161823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_karachi['purpose']=df_karachi['purpose'].replace('For Sale','fr')
# C:\Users\progr\AppData\Local\Temp\ipykernel_7036\3392161823.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_karachi['purpose']=df_karachi['purpose'].replace('For Sale','fs')
#         property_id  location_id  \
# 156           86575         6649
# 161         1010365         1674
# ...

# %%
df.columns
# Out:
# Index(['property_id', 'location_id', 'page_url', 'property_type', 'price',
#        'location', 'city', 'province_name', 'latitude', 'longitude', 'baths',
#        'purpose', 'bedrooms', 'date_added', 'agency', 'agent', 'Total_Area'],
#       dtype='object')

# %%
df_karachi['date_added']=pd.to_datetime(df_karachi['date_added'],errors='coerce')

df_karachi
# Out:
# C:\Users\progr\AppData\Local\Temp\ipykernel_7036\3057930037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_karachi['date_added']=pd.to_datetime(df_karachi['date_added'],errors='coerce')
#         property_id  location_id  \
# 156           86575         6649
# 161         1010365         1674
# 163         1260475         6861
# 164         1631292         1483
# 165         1902788         6853
# ...             ...          ...
# 168441     17355248         6754
# 168442     17355249          680
# 168443     17355250         6757
# 168444     17355251         6752
# 168445     17355287        10045
#
#                                                  page_url property_type  \
# ...

# %%
year=df_karachi[df_karachi['date_added'] > '2019-05-05']
year
# Out:
#         property_id  location_id  \
# 156           86575         6649
# 161         1010365         1674
# 163         1260475         6861
# 164         1631292         1483
# 165         1902788         6853
# ...             ...          ...
# 168441     17355248         6754
# 168442     17355249          680
# 168443     17355250         6757
# 168444     17355251         6752
# 168445     17355287        10045
#
#                                                  page_url property_type  \
# 156     https://www.zameen.com/Property/faisal_cantonm...         House
# 161     https://www.zameen.com/Property/dha_defence_dh...         House
# 163     https://www.zameen.com/Property/gulshan_e_iqba...          Flat
# 164     https://www.zameen.com/Property/d_h_a_dha_phas...         House
# 165     https://www.zameen.com/Property/scheme_33_saad...         House
# ...                                                   ...           ...
# ...

# %%
df_karachi_rent=df_karachi[df_karachi['purpose']=='fr']
df_karachi_rent
# Out:
#         property_id  location_id  \
# 156           86575         6649
# 161         1010365         1674
# 163         1260475         6861
# 164         1631292         1483
# 165         1902788         6853
# ...             ...          ...
# 168441     17355248         6754
# 168442     17355249          680
# 168443     17355250         6757
# 168444     17355251         6752
# 168445     17355287        10045
#
#                                                  page_url property_type  \
# 156     https://www.zameen.com/Property/faisal_cantonm...         House
# 161     https://www.zameen.com/Property/dha_defence_dh...         House
# 163     https://www.zameen.com/Property/gulshan_e_iqba...          Flat
# 164     https://www.zameen.com/Property/d_h_a_dha_phas...         House
# 165     https://www.zameen.com/Property/scheme_33_saad...         House
# ...                                                   ...           ...
# ...

# %%
df_karachi_rent['property_type'].unique()
# Out:
# array(['House', 'Flat', 'Penthouse', 'Upper Portion', 'Lower Portion',
#        'Farm House', 'Room'], dtype=object)

# %%
filtered_flats=df_karachi_rent[df_karachi_rent['property_type'] == 'Flat']
filtered_flats
# Out:
#         property_id  location_id  \
# 163         1260475         6861
# 166         2290028         6655
# 167         2290030         6655
# 168         2290031         6655
# 169         2290032         6655
# ...             ...          ...
# 168299     17353515         7220
# 168303     17353537         6840
# 168434     17354106        10030
# 168435     17354110        10030
# 168440     17355247         6760
#
#                                                  page_url property_type  \
# 163     https://www.zameen.com/Property/gulshan_e_iqba...          Flat
# 166     https://www.zameen.com/Property/malir_cantonme...          Flat
# 167     https://www.zameen.com/Property/malir_cantonme...          Flat
# 168     https://www.zameen.com/Property/malir_cantonme...          Flat
# 169     https://www.zameen.com/Property/malir_cantonme...          Flat
# ...                                                   ...           ...
# ...

# %%
df_karachi_rent.columns
# Out:
# Index(['property_id', 'location_id', 'page_url', 'property_type', 'price',
#        'location', 'city', 'province_name', 'latitude', 'longitude', 'baths',
#        'purpose', 'bedrooms', 'date_added', 'agency', 'agent', 'Total_Area'],
#       dtype='object')

# %%
df_karachi_rent= df_karachi_rent.drop(columns=['location_id','province_name','latitude','longitude'],inplace=False)

# %%
df_karachi_rent
# Out:
#         property_id                                           page_url  \
# 156           86575  https://www.zameen.com/Property/faisal_cantonm...
# 161         1010365  https://www.zameen.com/Property/dha_defence_dh...
# 163         1260475  https://www.zameen.com/Property/gulshan_e_iqba...
# 164         1631292  https://www.zameen.com/Property/d_h_a_dha_phas...
# 165         1902788  https://www.zameen.com/Property/scheme_33_saad...
# ...             ...                                                ...
# 168441     17355248  https://www.zameen.com/Property/gulshan_e_maym...
# 168442     17355249  https://www.zameen.com/Property/gadap_town_gul...
# 168443     17355250  https://www.zameen.com/Property/gulshan_e_maym...
# 168444     17355251  https://www.zameen.com/Property/gulshan_e_maym...
# 168445     17355287  https://www.zameen.com/Property/bahria_town_ka...
#
#        property_type      price              location     city  baths purpose  \
# ...

# %%
df_karachi_rent=df_karachi_rent[df_karachi_rent['baths'] !=0]

df_karachi_rent
# Out:
#         property_id                                           page_url  \
# 156           86575  https://www.zameen.com/Property/faisal_cantonm...
# 161         1010365  https://www.zameen.com/Property/dha_defence_dh...
# 163         1260475  https://www.zameen.com/Property/gulshan_e_iqba...
# 164         1631292  https://www.zameen.com/Property/d_h_a_dha_phas...
# 165         1902788  https://www.zameen.com/Property/scheme_33_saad...
# ...             ...                                                ...
# 168436     17354114  https://www.zameen.com/Property/bahria_town_ka...
# 168437     17354117  https://www.zameen.com/Property/bahria_town_pr...
# 168438     17354433  https://www.zameen.com/Property/bahria_town_ka...
# 168439     17355068  https://www.zameen.com/Property/bahria_town_ka...
# 168445     17355287  https://www.zameen.com/Property/bahria_town_ka...
#
#        property_type      price              location     city  baths purpose  \
# ...

# %%
df_karachi_rent['bedrooms'].unique()
# Out:
# array([ 6,  4,  5,  3,  2,  1,  9,  0,  8,  7, 11, 10, 16], dtype=int64)

# %%
df_karachi_rent=df_karachi_rent[df_karachi_rent['bedrooms'] != 0]

#Ready Data of Karachi rent houses

df_karachi_rent
# Out:
#         property_id                                           page_url  \
# 156           86575  https://www.zameen.com/Property/faisal_cantonm...
# 161         1010365  https://www.zameen.com/Property/dha_defence_dh...
# 163         1260475  https://www.zameen.com/Property/gulshan_e_iqba...
# 164         1631292  https://www.zameen.com/Property/d_h_a_dha_phas...
# 165         1902788  https://www.zameen.com/Property/scheme_33_saad...
# ...             ...                                                ...
# 168436     17354114  https://www.zameen.com/Property/bahria_town_ka...
# 168437     17354117  https://www.zameen.com/Property/bahria_town_pr...
# 168438     17354433  https://www.zameen.com/Property/bahria_town_ka...
# 168439     17355068  https://www.zameen.com/Property/bahria_town_ka...
# 168445     17355287  https://www.zameen.com/Property/bahria_town_ka...
#
#        property_type      price              location     city  baths purpose  \
# ...

# %%
df_karachi_rent['location'].unique()
# Out:
# array(['Cantt', 'DHA Defence', 'Gulshan-e-Iqbal Town', 'Scheme 33',
#        'Malir', 'Falcon Complex Faisal', 'Gizri',
#        'Navy Housing Scheme Karsaz', 'Bahria Town Karachi',
#        'Gulistan-e-Jauhar', 'Jinnah Avenue', 'North Nazimabad', 'Clifton',
#        'Northern Bypass', 'Fazaia Housing Scheme', 'Shaheed Millat Road',
#        'Bath Island', 'Defence View Society', 'Sea View Apartments',
#        'Zamzama', 'Jamshed Town', 'Liaquatabad', 'Delhi Colony',
#        'Nazimabad', 'Korangi', 'Kashmir Road', 'Federal B Area',
#        'North Karachi', 'KDA Scheme 1', 'Garden West',
#        'Naval Housing Scheme', 'DHA City Karachi', 'Scheme 45',
#        'Sindh Industrial Trading Estate (SITE)', 'Civil Lines',
#        'Tariq Road', 'Azam Town', 'PAF Housing Scheme', 'Bin Qasim Town',
#        'Gadap Town', 'Korangi Road', 'New Karachi', 'Al-Hilal Society',
#        'Mehmoodabad', 'Naya Nazimabad', 'Shah Faisal Town',
# ...

# %%
df_karachi_rent_malir=df_karachi_rent[df_karachi_rent['location'] == 'Malir']

df_karachi_rent_malir
# Out:
#         property_id                                           page_url  \
# 180         3011860  https://www.zameen.com/Property/malir_falcon_c...
# 181         3011866  https://www.zameen.com/Property/malir_falcon_c...
# 182         3011868  https://www.zameen.com/Property/malir_falcon_c...
# 183         3011910  https://www.zameen.com/Property/malir_falcon_c...
# 184         3011916  https://www.zameen.com/Property/malir_falcon_c...
# ...             ...                                                ...
# 158710     17306155  https://www.zameen.com/Property/malir_saudabad...
# 163157     17323198  https://www.zameen.com/Property/malir_saima_ji...
# 164322     17331380  https://www.zameen.com/Property/malir_khokhrap...
# 164339     17331878  https://www.zameen.com/Property/malir_khokhrap...
# 166303     17340541  https://www.zameen.com/Property/malir_saudabad...
#
#        property_type     price location     city  baths purpose  bedrooms  \
# ...

# %%
df_karachi_rent_malir['price'].min()

done=df_karachi_rent_malir[df_karachi_rent_malir['price'] == 25000]

# %%
done['page_url']
# Out:
# 130809    https://www.zameen.com/Property/malir_model_co...
# Name: page_url, dtype: object

# %%
df_karachi
# Out:
#         property_id  location_id  \
# 156           86575         6649
# 161         1010365         1674
# 163         1260475         6861
# 164         1631292         1483
# 165         1902788         6853
# ...             ...          ...
# 168441     17355248         6754
# 168442     17355249          680
# 168443     17355250         6757
# 168444     17355251         6752
# 168445     17355287        10045
#
#                                                  page_url property_type  \
# 156     https://www.zameen.com/Property/faisal_cantonm...         House
# 161     https://www.zameen.com/Property/dha_defence_dh...         House
# 163     https://www.zameen.com/Property/gulshan_e_iqba...          Flat
# 164     https://www.zameen.com/Property/d_h_a_dha_phas...         House
# 165     https://www.zameen.com/Property/scheme_33_saad...         House
# ...                                                   ...           ...
# ...
